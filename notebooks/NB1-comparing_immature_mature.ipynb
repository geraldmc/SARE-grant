# %%
import os
# %run ../lib/spectral_lib.py

# %%
# Data path relative to this location.
base_path = '../data/imagesets'
sample1, date1 = get_path(base_path, '/2017-04-25/', '001_3')
sample2, date2 = get_path(base_path, '/2017-07-28/', '021_3')

pos_score1 = '001_3'
pos_score2 = '021_3'

# %%
src_grayscale_sample1 = get_greyscale(sample1, date1, pos_score1)
src_grayscale_sample2 = get_greyscale(sample2, date2, pos_score2)

NDVI_sample1 = calc_ndvi(src_grayscale_sample1)
NDVI_sample2 = calc_ndvi(src_grayscale_sample2)

GNDVI_sample1 = calc_gndvi(src_grayscale_sample1)
GNDVI_sample2 = calc_gndvi(src_grayscale_sample2)

# %%
filename1=base_path + '/2017-04-25/2017-04-25_001_3_CIR.png'

# %%
from IPython.display import Image
Image(filename1)

# %%
from matplotlib import pyplot as plt
plt.matshow(NDVI_sample1, cmap=fastie_lut_cmap)
plt.colorbar(orientation='vertical')
fig = plt.gcf()
#fig.savefig('../readme_resources/img/2017-04-25_001_3_NDVI.png', format='png')
plt.show()
print ('Original NDVI image: ' 
       + str(date1) + ', ' 
       + str(pos_score1) + ', N treatment was 04/19/2017')
# Out:
# Original NDVI image: 2017-04-25, 001_3, N treatment was 04/19/2017

# %%
plt.matshow(GNDVI_sample1, cmap=fastie_lut_cmap)
plt.colorbar(orientation='vertical')
fig = plt.gcf()
#fig.savefig('../readme_resources/img/2017-04-25_001_3_GNDVI.png', format='png')
plt.show()
print ('Original GNDVI image: ' 
       + str(date1) + ', ' 
       + str(pos_score1) + ', N treatment was 04/19/2017')
# Out:
# Original GNDVI image: 2017-04-25, 001_3, N treatment was 04/19/2017

# %%
filename2=base_path + '/2017-07-28/2017-07-28_021_3_CIR.png'
from IPython.display import Image
Image(filename2)

# %%
plt.matshow(NDVI_sample2, cmap=fastie_lut_cmap)
plt.colorbar(orientation='vertical')
fig = plt.gcf()
#fig.savefig('../readme_resources/img/2017-07-28_021_3_NDVI.png', format='png')
plt.show()
print ('Original NDVI image: ' 
       + str(date2) + ', ' 
       + str(pos_score2) + ', N treatment was 04/19/2017')
# Out:
# Original NDVI image: 2017-07-28, 021_3, N treatment was 04/19/2017

# %%
plt.matshow(GNDVI_sample2, cmap=fastie_lut_cmap)
plt.colorbar(orientation='vertical')
fig = plt.gcf()
#fig.savefig('../readme_resources/img/2017-07-28_021_3_GNDVI.png', format='png')
plt.show()
print ('Original GNDVI image: ' 
       + str(date2) + ', ' 
       + str(pos_score2) + ', N treatment was 04/19/2017')
# Out:
# Original GNDVI image: 2017-07-28, 021_3, N treatment was 04/19/2017
